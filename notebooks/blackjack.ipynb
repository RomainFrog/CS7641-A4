# %% [markdown]
# # Blackjack
# Planner __init__ expects a reward and transition matrix P, which is a nested dictionary
# [OpenAI Gym](https://www.gymlibrary.ml/) style discrete environment where
# P[state][action] is a list of tuples (probability, next state, reward, terminal).
#
# The gym blackjack environment does not include this matrix, so we'll use the BlackjackWrapper class to create a wrapped gym environment, which modifies the observation space and includes P.

# %%
# !pip install bettermdptools
# Out:
# Requirement already satisfied: bettermdptools in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (0.6.0)
# Requirement already satisfied: gymnasium<=0.26.3,>=0.26 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (0.26.3)
# Requirement already satisfied: pygame in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (2.5.2)
# Requirement already satisfied: numpy in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (1.24.3)
# Requirement already satisfied: tqdm in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (4.66.1)
# Requirement already satisfied: pandas in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (2.1.4)
# Requirement already satisfied: seaborn in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (0.12.2)
# Requirement already satisfied: matplotlib in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from bettermdptools) (3.8.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from gymnasium<=0.26.3,>=0.26->bettermdptools) (3.0.0)
# Requirement already satisfied: gymnasium-notices>=0.0.1 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from gymnasium<=0.26.3,>=0.26->bettermdptools) (0.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (23.2)
# Requirement already satisfied: pillow>=8 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from matplotlib->bettermdptools) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from pandas->bettermdptools) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from pandas->bettermdptools) (2023.3)
# Requirement already satisfied: six>=1.5 in /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->bettermdptools) (1.16.0)

# %%
import gymnasium as gym
from bettermdptools.utils.blackjack_wrapper import BlackjackWrapper
from bettermdptools.utils.test_env import TestEnv
from bettermdptools.algorithms.planner import Planner
from bettermdptools.algorithms.rl import RL
import numpy as np

# %%
base_env = gym.make('Blackjack-v1', render_mode=None)
blackjack = BlackjackWrapper(base_env)

# run VI
V, V_track, pi, pi_track, timings = Planner(blackjack.P).value_iteration()

#test policy
test_scores = TestEnv.test_env(env=blackjack, n_iters=100, render=False, pi=pi, user_input=False)
print(np.mean(test_scores))

# Q-learning
Q, V, pi, Q_track, pi_track = RL(blackjack).q_learning()

#test policy
test_scores = TestEnv.test_env(env=blackjack, n_iters=100, render=False, pi=pi, user_input=False)
print(np.mean(test_scores))
# Out:
# /home/romain/anaconda3/envs/ML/lib/python3.11/site-packages/gymnasium/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# Total Q updates: 37272
# runtime = 0.02 seconds
# 0.72
# runtime = 0.93 seconds
# 0.735

# %%
blackjack._P.items()
# Out:
# dict_items([(0, {0: [(0.6463918636046386, -1, -1.0, True), (0.35360813639536137, -1, 1.0, True)], 1: [(0.07692307692307693, 20, 0.0, False), (0.07692307692307693, 30, 0.0, False), (0.07692307692307693, 40, 0.0, False), (0.07692307692307693, 50, 0.0, False), (0.07692307692307693, 60, 0.0, False), (0.07692307692307693, 70, 0.0, False), (0.07692307692307693, 80, 0.0, False), (0.07692307692307693, 90, 0.0, False), (0.3076923076923077, 100, 0.0, False), (0.07692307692307693, 210, 0.0, False)]}), (1, {0: [(0.6261251146178569, -1, -1.0, True), (0.37387488538214325, -1, 1.0, True)], 1: [(0.07692307692307693, 21, 0.0, False), (0.07692307692307693, 31, 0.0, False), (0.07692307692307693, 41, 0.0, False), (0.07692307692307693, 51, 0.0, False), (0.07692307692307693, 61, 0.0, False), (0.07692307692307693, 71, 0.0, False), (0.07692307692307693, 81, 0.0, False), (0.07692307692307693, 91, 0.0, False), (0.3076923076923077, 101, 0.0, False), (0.07692307692307693, 211, 0.0, False)]}), (2, {0: [(0.6055315544974572, -1, -1.0, True), (0.3944684455025429, -1, 1.0, True)], 